# %% [markdown]
# # Quiz : Pyplot basics

# %%
import matplotlib.pyplot as plt
plt.style.use(["seaborn-whitegrid"])

# %%
import pandas as pd

# the data we'll use
data = pd.read_csv('https://raw.githubusercontent.com/DA4BAM/dataset/master/temperature.csv')
data.head(10)
# Out:
#    year  week   AvgTemp
# 0  2010     1 -3.000000
# 1  2010     2 -7.500000
# 2  2010     3 -7.900000
# 3  2010     4 -2.357143
# 4  2010     5 -3.342857
# 5  2010     6 -1.800000
# 6  2010     7 -0.314286
# 7  2010     8 -2.142857
# 8  2010     9  4.400000
# 9  2010    10  7.057143

# %% [markdown]
# # Q1. Draw the scatter plot
#
# * x-axis : 'week' column in data
# * y-axis : 'AvgTemp' column in data

# %%
####################
## your code here ##
####################

plt.figure(figsize=(7, 7))
plt.scatter(x=data['week'], y=data['AvgTemp'])
plt.show()

# %% [markdown]
# # Q2. Draw the bar plot
# * x-axis : 'year' column in data
# * y_axis(height) : mean of 'AvgTemp' column in data by year

# %%
####################
## your code here ##
####################

temp = data.groupby(by=['year'], as_index=False)['AvgTemp'].mean()

plt.figure(figsize=(7, 5))
plt.bar(x=temp['year'], height = temp['AvgTemp'])
plt.show()
